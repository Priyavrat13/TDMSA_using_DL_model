# %%
news_list = ['pennewstweet', 'naashonomics', 'indiablooms', 'firstpost', '2019LSElections', 'mathrubhuminews', 'ZeeNews',
             'ians_india', 'BloombergQuint', 'tv9kannada', 'bsindia', 'moneycontrolcom', 'NewsroomPostCom', 'MyNation',
             'DeccanChronicle', 'ceopuducherry', 'TheQuint', 'ECISVEEP', 'mathrubhumieng', 'PratibaRaman', 'scroll_in',
             'DDNewsLive', 'MirrorNow', 'NH_India', 'EconomicTimes', 'epatrakaar', 'IndiaToday', 'latestly', 'NewsNationTV',
             'FinancialXpress', 'CatchNews', '1stIndiaNews', 'CPIM_WESTBENGAL', 'LeadtechIndia', 'IndiaAheadNews',
             'mantralayatimes', 'apnnewsindia', 'htTweets', 'news24tvchannel', 'ceonagaland', 'Outlookindia', 'dna',
             'NewsMobileIndia', 'ETNOWlive', 'databaaz', 'WeForNews', 'tv9gujarati', 'WIONews', 'ndtv', 'timesofindia',
             'PIB_India', 'TheFederal_IN', 'insidene', 'Poll2019India', 'madhusudan41', 'daylivenews', 'mathrubhumi',
             'ReutersIndia', 'HouseOfMohit', 'lftfd', 'TheBoringTweet', 'abpnewstv', 'NewIndianXpress', 'NewsHtn',
             'hpelection', 'newsmen_in', 'TheLeaflet_in', 'newstrackmedia', 'indiatvnews', 'AsiavilleNews', 'ANI', 'CNNnews18',
             'Reuters', 'DeccanHerald', 'BiIndia', 'the_hindu', 'milligazette', 'DadaScream', 'gopalreports', 'NewsStoryIndia',
             'DailyhuntApp', 'IndianExpress', 'airnewsalerts', 'Oneindia', 'editorji', 'dhavalkulkarni', 'CEO_Maharashtra',
             'TheCEOPunjab', 'sivaetb', 'businessline', 'RediffNews', 'NewsX', 'VikramKMalkani', 'Nation1stNews',
             'silverscreenin', 'electionaddaEN', 'ceoup', 'HRITHIKSAINI1', 'DDIndiaLive', 'ibtimes_india', 'rohanduaTOI',
             'ormiga', 'NEWS9TWEETS', 'OnmanoramaLive', 'khaleejtimes', 'BT_India', 'ChaiMIRROR', 'ACLEDINFO', 'BTVI',
             'EG_Collector', 'DeoDnh', 'UttarakhandCEO', 'NewsGujarati', 'news18dotcom', 'thenglishpost', 'dt_next',
             'PursueRam', 'sriniva13801402', 'lok2019sabha', 'CeoRajasthan', 'mzelection', 'Rama_Krishnan', 'nistula',
             'guwahatiplus', 'VoteVoice_News', 'naseerCorpGhmc', 'YahooIndia', 'BhattNaturally1', 'fpjindia', 'time8news',
             'Spick_Media', 'myministers', 'RKRadhakrishn', 'Kalingatv24x7', 'Afternoon_Voice', 'devsark', 'GetNewsd',
             'GorwayGlobal', 'sharanpoovanna', 'SVEEP_Chittor', 'indsamachar', 'themirror01', 'decision2019', 'ceodamandiu',
             'AJStream', 'airnews_hyd', 'PoliticalIndiaV', 'kalyugyaar', 'crowswami', 'pratidintime', 'Election_in', 'CrruxHQ',
             'Bhuvanbagga', 'Info_Prayagraj', 'anujajTOI', 'indusdotnews', 'EurasiaGroup', 'smitha_tk', 'mymoneykarma',
             'stevereports', 'Tolivelugu', 'electionfactsin', 'Eenadu_English', 'DynamiteNews_', 'TheWeekLive', 'UK4Modi2019',
             'SAVoices', 'YoungINDYI', 'urbanyogie', 'SagarSpeaksNews', 'mytentaran', 'CNBCTV18Live', 'nc24x7', 'JioNews',
             'cineobserver', 'indiacom', 'BengalNewzIndia', 'thecaravanindia', 'digitaljournal', 'eartherian', 'VeblrOfficial',
             'TheNationalUAE', 'IndiaSpend', 'Khabar_Bar', 'Bugsabee', 'ElectionsnIndia', 'MumbaiLiveNews', 'theindianwire',
             'AyodhyaUP42', 'ndtv','IndiaToday','htTweets','aajtak', 'TheQuint', 'ANI_multimedia', 'ndtvvideos', 'PTI_News',
             'EconomicTimes', 'ABPNews', 'GoNews_India', 'TNT_Magazine', 'IndiaAheadNews', 'The_NewsMill', 'OpIndia_in',
             'ie_seven', 'FactIndia_News', 'JioNews', 'navjivanindia', 'EastMojo', 'MirrorNow', 'latestly', 'newslaundry',
             'pratidintime', 'firstpost', 'NewsNationTV', 'VtvGujarati', 'JanasanyogB', 'WFNhindi', 'FactAssamese',
             'Outlookindia', 'PTTVOnlineNews', 'OneindiaVideos', 'indiacom', 'oneindiaHindi', 'thewirehindi', 'thetribunechd',
             'prajavani', 'dna', 'punjabkesari', 'TezChannel', 'uniindianews', 'IndiaTomorrow_', 'sbmg_assam', 'IndiaNews_itv',
             'News18Odia', 'moneycontrolcom', 'IndiaPost_News', 'MoneycontrolH', 'WeForNews', 'IANSKhabar', 'time8news',
             'ConnectGujarat', 'editorji', 'ETNOWlive', 'viralvdoz', 'sblhindustan', 'nayaindianews', 'nlhindi', 'TheWireUrdu',
             'sinceindmedia', 'newsforsocial', 'publictvnews', 'GetNewsd', 'IndiaTomorrow_ ', 'CPJAsia', 'ToThePoint_News',
             'HNN24X7', 'SatyaHindi', 'Kalaignarnews','Divya_Bhaskar', 'indiatvnews', 'TV9Bharatvarsh','GulistanNewsTV',
             'NewsFirstKan', 'nedricknews', 'publictvnews', 'eenadulivenews','OpinionExpress', 'apn_10','thewire_in',
             'DDNewsGujarati', 'frontline_india','TruecopyThink','WeForNews','bsindia','WINNEWS_IN', 'PixstoryApp', 'NH_India',
             'ndtvvideos','smitha_tk','FinancialXpress','NewsMobileIndia','Onmanorama','Deepika_News', 'EconomicTimes','DainikHint',
             'PatrikaNews', 'prajavani', 'opinionmaster','News18Odia','DynamiteNews_','AsianetNewsEN'
             'AHindinews','airnewsalerts', 'navjivanindia','ndtvindia','News1IndiaTweet','PTTVOnlineNews','AmarUjalaNews',
             'AsianetNewsML', 'ZHMalayalam', 'sebipaulkada', 'TheNatWide', 'IndiaToday', 'naashonomics', 'thatsMalayalam',
             'xpresskerala', 'Ceokerala', 'htTweets', 'ANI', 'IndiaAheadNews','thenewsminute', 'newslaundry', 
             'ndtv', 'BandanaMrs', 'INCKerala', 'politicalbaaba', 'ConnectGujarat','theind_india','IANSKhabar','JioNews',
             'IT_Malayalam','ABPNews','JioNews','NewIndianXpress','PIBTvpm','thefirstindia','Outlookindia','Zee_Hindustan',
             'IeMalayalam', 'KeralaShortwave','Indsamachar','Dailyaddaa','News18Kerala','timesofindia','aajtak','MirrorNow',
             'DainikBhaskar','JagranEnglish','thomasJins','tv9kannada','moneycontrolcom','george_TNIE','AsianetNewsHN',
             'IBC24News', 'LoudIndiaTV','ZeeNewsEnglish','TatwamayiNews', 'gulf_news','nlhindi','tahalka_express','TezChannel',
             'TamilTheHindu', 'editorji','TheLeaflet_in','ANI_multimedia','Oneindia','MAITV_Telugu','News1IndiaTweet',
             'TatwamayiNews','deshsewaknews', 'malluTrollVideo','thatsMalayalam','mathrubhuminews','TatwamayiNews',
             'PuberKalomDaily','NEWS9TWEETS','TheNatWide', 'Dailyaddaa','OneindiaKannada','MBCTVODISHA','MediaOneTVLive',
             '24onlive','AakeruNews','manoramanews','madhyamam', 'SamayamM', 'mathrubhumieng','TheHansIndiaWeb','toptamilnews',
             'polimernews','updatenews360','ibctamilmedia', 'sunnewstamil','TamilMintNews','fpjindia','TheWeekLive','thehawk',
             'thatsTamil','LoksattaLive','ThanthiTV','WINNEWS_IN', 'ANI','htTweets','sunnewstamil','IndiaToday','updatenews360',
             'pondy_live','MalaimurasuTv','Oneindia','Thalayangamnews', 'IndiaAheadNews','polimernews','jayapluschannel',
             'fpjindia','JioNews','ConnectGujarat','news7tamil','JagranEnglish', 'aajtak','Zee_Hindustan','TooLoudTamil',
             'AsianetNewsEN','filmistreet','nakkheeranweb','JK247News', 'SicilianSpeake1', 'adrspeaks','ZeeNewsEnglish',
             'galattadotcom','velichamtvtamil','NATIONALNEWSDM','News18TamilNadu','AHindinews','Opoyis', 'NewsJTamil','BiIndia',
             'NewsroomPostCom','VidhaiNews','VOT24x7','vot24x7world','NAMMANEWS_','NTVJustIn','abstarnews01', 'ETVBharatOD',
             'janamtvenglish','OfficialJioTV','TamildiaryIn','News18Bengali','PunjabKesariCom','TheDailyPioneer','ibctamilmedia',
             'sunnewstamil','TamilMintNews','fpjindia','TheWeekLive','thehawk','thatsTamil','galattadotcom','maalaimalar',
             'jananaayakan','dt_next','desiyasiragugal','THChennai','kumudamdigi','nakkheeranweb','behindwoods','IbcTamilnadu',
             'Moviebehindin','TamilcinemaSpl','2021_tamilnadu','citizenmatters','DeccanHerald','IndiaTrendDaily',
             'XavierMariabell','xpresstn','orangetalkies','kalakkalcinema','orangetalkies','KollywoodCinima','GOT_TN2021',
             'SamayamTamil', 'chennaicorp','offcl_aps','46Mmp','PrabuTaalkies','MuraliTalks','Congress300seat','anugula',
             'skarthikdotin', 'tamilpulikesi23','filmcrazymedia','BRbluebrigade','Priyan_reports','ADMKITWING_TN60',
             'koushiktweets','CinemaAcademyIn', 'rameshlaus','Collector_Try','yesbeeyes','ippodhu','diarekhiET','hindutalkies',
             'ADMK_PMK_BJP','DDMurthyAMMK','New_India7', 'cinemapluz11','dinakaranonline','InfosecIndian','UVCommunication',
             'AshokkumarMLA','Meme____creator','VE23VJAY', 'ciperon', 'Devanayagam', 'smsukumarofl', 'kadalkaattru',
             'kayaldevaraj', 'seithipunal', 'jaitrejait', 'ArjunanDurai', 'Manikandanraj92', 'idiamondbabu', 'Shivaram9341',
             'lavanyadeepak', 'SankarMahhaRajh', 'alakshya2', 'VijayIsMyLife', 'AMR_ARMY1', 'iamkapilan', 'Jay_Apoorva18',
             'masterg26333927', 'Chinnathirai3', 'SaketRam10', 'sjeeva26', 'chidamb77969184', 'arunananth', 'thirupathy2',
             'pathan_sumaya', 'Radacristhna', 'AzeefaFathima', 'raja_subash', 'Sivaji_KS', 'ShruthiAsabird', 'ItzmeOffl',
             'KanimozhiDMK', 'Aimim_Raebareli', 'SvsMaharani', 'NairShilpa1308', 'dinamalarweb', 'TNelectionsCEO',
             'itz_satheesh2', 'endrumchennai', 'AImtiyazi', 'MohdRashedFaraz', 'EngineerKpn', 'aravindh6666', 'Cinewoodsoffl',
             'Vff_officials', 'Saislakshmanan', 'Karthick_tweets', 'sharadaramanat1', 'SUDHARSANAM_S', 'Justwatchreview',
             'DSelvamoorthy', 'dsureshkumar', 'ZHindustanTamil', 'vazhapadi', 'SalikaShah6', 'Thuklakboy', 'Nandhini_Anandn',
             'anna_isaac', 'AvickSaha_', 'kaultheking', 'The_Abinesh', 'sivaetb', 'ArulrubanD', 'meghakaveri', 'mum_tamilmakkal',
             'the_hindu', 'Opskarthik', 'KollywoodStar_', 'cMiaTamil', 'RajivkrishnanS', 'Cini_Mini1', 'KhssnKk', 'tamilnadurjd',
             'tnrags', 'realunnikrish', 'avantika213', 'Biker_PraveenAK', 'umasudhir', 'Augusti07158865', 'Ramya_saiva',
             'dilipkumarmdk', '2daycinema1', 'POUNRAJS19', 'vani_trish', 'manojku91995139', 'CTRavi_BJP', 'CineTimee',
             'Captain_ketavan', 'yuganOffcial', 'kripu_vijaywada', 'SRajaJourno', 'trolee_', 'itz_chillax', 'Anyone2300000',
             'TamilarThaagam', 'Vj_master_642', 'proyuvraaj', 'ThalaSudharshan', 'Madrassan_Pinky', 'IamGowris', 'vikatan',
             'thandoratimes', 'skillhai1', 'Snow22112933', 'tamilchair2', 'I_Surya77', 'saibabu0814091', 'KollyUpdates',
             'Vikrama46999650', 'rs_prakash3', 'Mugilan__C', 'ARUNPAN69489447', 'ADiravia', 'thatbigdesidude', 'KannanVfc13',
             'LeoSimha', 'justsayingagai1', 'DinasuvaduTamil', 'KKarthik589', 'MThamar68996354', 'imanojprabakar', 'MumbaiBloke',
             'aimim_hussain_', 'Harrylokesh18', 'steevwow', 'sandhyaravishan', 'jeyahirthi', 'ivyasaa', 'shafinsha_1798',
             'ArunVarman2022', 'cineulagam', 'SekarSe48019667', 'tamilveedhi', 'jvidyasagar', 'mannar_mannan', 'Dheeban88037441',
             'Ganesh_265', 'SamparkRaj1', 'nellaiseemai', 'IamWeijia', 'prosathish', 'natshathiram', 'a_xeve2y', 'FascismTalks',
             'jeganebenezar1', 'tamizhvalai', 'bydivyac', 'valluvan87', 'Ramakri74350460', 'Magaraja2021', 'ArfaBahresh',
             'VOICEFORAMMK', 'HamithaThaslima', 'IeTamil', 'Tamil1980', 'Rasu4thalapathi', 'collrpmb1', 'PremAna74948064',
             'ElaSelvan4mnm', 'Ashokb444', 'senior_tamilan', 'cini_villa', 'aSmallSharp', 'aimim_national', 'Rajali1910', 
             'vikranthprasann', 'Tamil1947', 'Chrissuccess', 'Cinibeats2', 'SIVANAN42495688', 'IamSellvah', 'Im_kannanj',
             'Rajtwittz', 'metadoors', 'TheCommuneMag', 'KeerthikaAiadmk', 'NaveenSTR16', 'Rcky35029503', 'LOCKDOWNOFFL',
             'UttarandhraNow', 'SadhanaKrishna5', 'Its_harishu', 'aandavaaaa', 'kadalaimuttaai', 'codingbitz_dev', 'pibchennai',
             'nallaganesh', 'major_madhan', 'Now_Abhi82', 'WallPoster2020', 'arulkrishnanms', 'karthik_thinks', 'UNKHOurPride',
             'fan_girl_str_', 'uniqsiddarth99', 'Cine_Writers', 'Dineshk58354058', 'Troll_Cinema', 'EKadhirvel', 'joker_errorss',
             'OnlineVijayFC', 'cinemascopetaml', 'sekartweets', 'kollywoodTalkes', 'premjourn', 'JohnIyyappan', 'newcinemaexpres',
             'HinduValaiyar', 'ShaLateef', 'realityshoov', 'TamilanNewz', 'DravidianHere', 'fanaticbuff', 'kamalianism',
             'VigneshKattura1', 'MohdAhmedAIMIM', 'SamugamCine', 'hemananth_pro', 'PARITHITAMIL', 'sang1983', 'thetamilnadunow',
             'karthickjourno', 'balu81211', 'kewinsamraja', 'Simbu_Shadows', 'ItsmeNJS', 'TalksOfCinema', 'KuthoosSheik',
             'CinemaTweetz', '_poorvaja', 'manipaiyanmp', 'vinee_says', 'Dhoni_satheesh', 'MukilanLl', 'sendilkmr90', 'Stalin__SP',
             'moviewingz', 'ThalaCr7', 'Dhanalakshmi123', 'Kollywoodent', 'kalyugyaar', 'Achuthabalan', 'karthik_bk64',
             'DMKforKPM', 'Jaga2e', 'PrakashPandianP', 'rajaram1891', 'ItsVersatileOff', 'barathraina56', 'pRaDs_09',
             'Rathinavani908', 'tncpim', 'Sarojiniranjani', 'Tweets_CS', 'LMKMovieManiac', 'bhuvan1190', 'FullOnCinema',
             'selva_itsme', 'majlis_aimim', 'Raghavr28433175', 'Hemakumar_STR', 'TCinewoods', 'mskteem', 'Arasiyal3',
             'Janakiraman51', 'ChainTweter', 'manojaiadmk', 'shaktividhi', 'kchari2', 'Remosharan77', 'AmmkariyalurS',
             'sakthi_yogeesh', 'OneindiaBengali', 'V4umedia_', 'chaand_mech', 'KTownReporter', 'MIS_RAJMAHAL_JH', 'VjEngr',
             'Netfreak555', 'yuvanmain', 'GVAMEMES1', 'Magi_offc', 'ganeshvrc', 'OfficeOfOPS', 'R_Induja', 'mrk9719', 'JoyalAsir',
             'Karthi_Yellow', 'babu_thanesh', 'Deoariyalur', 'SathyaPriya_Off', 'EatwithLob', 'CommonManMedia', 'santhoshexpress',
             'snandhu', 'SimbuRakesh7', 'bala55523', 'FilmyNagri', 'SK_BrosOfficial', 'hindki_jai', 'sendilanandan','mdmkofficial',
             'E7Tamil','riyazrahmankhan','chnharish','r_sakkarapani','ThennalurP', 'TNwithoutDMK','InigoIrudayaraj','WorldGuru12',
             'StalinudanTN','Durairaj_U','maprabham','Thamizhiniyan84','SuryahSG', 'KazhagamDaddy','DravidaThalaiva','NAMKALAIGNAR',
             'pcrjabastian','Aadhan_Tamil','devashak','mtamil12351436','vazhviyal', 'NijanthanK','nyayasthan','ThuglakD','arivalayam',
             'rchammu','Vijaymoorthi27','Logan20359853','143blueredblack','PeekayKalra', 'swamisub','Mmk_itwing','Murugan25727986',
             'itsme_rrr9438','Cinema_Soul','edwinarockia','tmmkhqofficial','KWTDMKIT', 'Pandya1013','Nan_than_gk','SenguttuvanSrm',
             'koolfriend4u','janavas1981','NTR_25','OhmAK60','JMaheshram','betaal56','AmmU_MaanU', 'krishnanveluppi','aransei',
             'kumargovindan','FactCheckTamil','SivaYp','GomatiSivam','shyaamprem','PKalivarathan','ashokavarthana1', 'RjSriram15',
             'VSMANI91232104','TamilExpresscom','FullTalks','RoadsideKalakki', 'MaeeshatMedia','ZeePunjabHH', 'Rajput_Boy_2018',
             'thetribunechd','dsrpatel_bhopal','TNNavbharat','aajtak','vikram140gulati','GutznGlory', 'HTPunjab','RajpalFogawat',
             'IndiaTVHindi','abpsanjha','TransparencyWS','BawaHS','yespunjab','Keh_ke_Le_Lunga', 'Republic_IndiaR','TransparencyWS',
             'KesariPunjab','nileshrajurkar1','ZeePunjabHH','Rajput_Boy_2018','ptcnews', 'dsrpatel_bhopal', 'UPTakOfficial',
             'Voice_OF_YuvaMP', 'ZEEUPUK', 'peoples_review', 'STAR_KollyWood', 'igtelugu', 'ChoiceHQ_Social', 'INCTamilNadu',
             'SevadalHP', 'ChennaiSFCSouth', 'Legal_bites','TimesNow','ani_digital', 'JournalistRafi', 'ShankarRahuls', 'Daxshin',
             'WaqarHasan1231', 'KhawazaMainUddi', 'sopreetha', 'SANTYonWEB', 'pradipB27643686', 'sjeeva26', 'sjeeva26',
             'Viralnews2021', 'rshnmnl', 'sjeeva26', 'pradipB27643686', 'pradipB27643686', 'syedimranhashmi', 'ajoydasgupta',
             'johncheeran', 'syedimranhashmi', 'rshnmnl', 'arvind_vajpeyi', 'sjeeva26', 'sjeeva26', 'dalmiageekanna',
             'meenakshinews', 'JournalistRafi', 'Nagesha_Nag', 'sopreetha', 'Siddharthrege09', 'sjeeva26', 'sopreetha', 'JournalistRafi',
             'meenakshinews', 'sjeeva26', 'ajoydasgupta', 'sjeeva26', 'priyaGurunathan', 'priyaGurunathan', 'JournalistRafi',
             'JournalistRafi', 'ninglunhanghal', 'Abhishek9904564', 'anoopkr75', 'pradipB27643686', 'Himansh13414792',
             'FactlySanjeev', 'kamranhusain_', 'danishmusheer1', 'Bavazir_network', 'syedimranhashmi', 'syedimranhashmi',
             'syedimranhashmi', 'ThegangeshJha', 'path2shah', 'VISHALMS90', 'SANTYonWEB', 'syedimranhashmi', 'DhaliwalNavjot5',
             'ajoydasgupta', 'DhaliwalNavjot5', 'karu8396', 'karu8396', 'saisatya14', 'Daxshin', 'JoshiDNShimla', 'FactlySanjeev',
             'Bavazir_network', 'syedimranhashmi', 'saisatya14', 'mukherjee_moy', 'mohitk1', 'pawanpjourno', 'karu8396',
             'CandidJourno', 'ninglunhanghal', 'thakur_ranjeev', 'DhaliwalNavjot5', 'mukherjee_moy',
             'karu8396', 'bhaskareco67', 'stoicyashraj', 'rajarshi81', 'arvind_vajpeyi', 'AnjaliMody1', 'sahankit17',
             'pradipB27643686', 'bhaskareco67', 'SHARATH_JOURNO', 'textmeman', 'textmeman', 'textmeman', 'guddumalik23', 'tweet_sandeep',
             'Mk1601Mk', 'venujitheboss', 'meenakshinews', 'textmeman', 'textmeman', 'VISHALMS90', 'Mishra_tak',
             'KMDKhaleel3', 'pradipB27643686', 'ChandraPPandey7', 'DhaliwalNavjot5', 'VISHALMS90', 'KMDKhaleel3', 'AadabZindagi',
             'arvind_vajpeyi', 'Jarnailnaffree', 'AllRNEWS', 'JournoAnup', 'thakur_ranjeev', 'ajoydasgupta', 'durgashrijk',
             'syedimranhashmi', 'ninglunhanghal',  'mohitk1', 'Mishra_tak', 'Jarnailnaffree', 'DhaliwalNavjot5',
             'rajaydeep1', 'Tyson81901', 'pradipB27643686', 'PatrkarShaikh', 'Mishra_tak', 'PopliDinkle', 'AmritJsl',
             'DhaliwalNavjot5', 'PopliDinkle', 'Abhishek9904564', 'Jarnailnaffree', 'tweet_sandeep', 'thakur_ranjeev',
             'saifi9643', 'chandratumkur', 'AyubKha87854248', 'danishmusheer1', 'babbarmohit', 'tweet_sandeep',
             'AyubKha87854248', 'ArnavMiOfficial', 'pradipB27643686', 'AdeelAltamash', 'AyubKha87854248', 'saisatya14',
             'tweet_sandeep', 'gajendr8005671', 'arvind_vajpeyi', 'thakur_ranjeev', 'EditorAbuFaisal', 'ArkaDeb52753854',
             'bhaskareco67', 'syedimranhashmi', 'thakur_ranjeev', 'bhaskareco67', 'syedimranhashmi']

# %%
news_list2 = ["tv", "TV", "news", "News", "channel", "Channel", "media", "Media", "NEWS", "news", "Media", "LIVE", "live",
              "Live", "TN", "TOI", "ET", "App", "AajTak"]

# %%
news_list3 = ["tv", "TV", "Tv", "handle", "Handle", "news", "News", "channel", "Channel", "media", "Media", "NEWS", "news",
              "Media", "LIVE", "live", "Live", "Journalism", "journalism", "Journalist", "journalist", "megazines", "Megazines",
              "megazine", "Megazines", "newspapers", "Newspapers", "Editor", "editor", "breaking", "Breaking", "Website",
              "website", "Podcasts", "podcast", "Podcast", "podcasts", "newspaper", "news portal", "latest news", "Latest news",
             "latest", "Latest"]

# %%
news_list4 = ["आईटी सेल", "प्रदेश अध्यक्ष", "जिला उपाध्यक्ष","देश-दुनिया","मिडिया सेल", "मिडिया","आई टी विभाग", "विभाग", "न्यूज", "समाचार",
              "समाचार पत्रिका", "खबरें", "न्यूज़ एजेंसी", "डिजिटल पोर्टल", "नेड्रिक न्यूज", "डिजिटल चैनल", "लेटेस्ट न्यूज़", "लेटेस्ट खबरों", "लॉग ऑन",
              "राष्ट्रीय समाचार पत्र", "खबर", "लेटेस्ट"]

# %%
news_list5 = ["tv", "TV", "news", "News", "channel", "media", "Media", "LIVE", "live", "TN", "TOI", "ET", "न्यूज", "समाचार",
              "खबरें", "न्यूज़ एजेंसी", "डिजिटल पोर्टल", "breaking न्यूज", "लेटेस्ट न्यूज़", "लेटेस्ट खबर", "राष्ट्रीय समाचार पत्र","breaking news"]

# %%
len(news_list)
# Out:
# 1061
